# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
city_position = [{'甘肃':[103.73, 36.03]},
{'青海':[101.74, 36.56]},
{'四川':[104.06, 30.67]},
{'河北':[114.48, 38.03]},
{'云南':[102.73, 25.04]},
{'贵州':[106.71, 26.57]},
{'湖北':[114.31, 30.52]},
{'河南':[113.65, 34.76]},
{'山东':[117, 36.65]},
{'江苏':[118.78, 32.04]},
{'安徽':[117.27, 31.86]},
{'浙江':[120.19, 30.26]},
{'江西':[115.89, 28.68]},
{'福建':[119.3, 26.08]},
{'广东':[113.23, 23.16]},
{'湖南':[113, 28.21]},
{'海南':[110.35, 20.02]},
{'辽宁':[123.38, 41.8]},
{'吉林':[125.35, 43.88]},
{'黑龙江':[126.63, 45.75]},
{'山西':[112.53, 37.87]},
{'陕西':[108.95, 34.27]},
{'台湾':[121.30, 25.03]},
# // 4直辖市
{'北京':[116.46, 39.92]},
{'上海':[121.48, 31.22]},
{'重庆':[106.54, 29.59]},
{'天津':[117.2, 39.13]},
# // 5自治区
{'内蒙古':[111.65, 40.82]},
{'广西':[108.33, 22.84]},
{'西藏':[91.11, 29.97]},
{'宁夏':[106.27, 38.47]},
{'新疆':[87.68, 43.77]},
# // 2特别行政区
{'香港':[114.17, 22.28]},
{'澳门':[113.54, 22.19]}]

# %%
from pyecharts.render import make_snapshot
from snapshot_phantomjs import snapshot

from pyecharts import options as opts
from pyecharts.charts import Geo
from pyecharts.globals import ChartType
def geo_effectscatter() -> Geo:

    # 初始化地图参数 page_title: 页面标题， theme: 画布主题（主题列表可见Echarts官网）
    InitOpts = opts.InitOpts(page_title="中国地图", theme="light")
    c = (
        # 声明对象时将初始化参数
        Geo(InitOpts)
        # 添加底部地图
        .add_schema(
            maptype="china")

        # 增加区域点
        .add_coordinate(name=city_names[0],longitude=city_geoCoord[0][0],latitude=city_geoCoord[0][1])
        .add_coordinate(name=city_names[1],longitude=city_geoCoord[1][0],latitude=city_geoCoord[1][1])
        .add_coordinate(name=city_names[2],longitude=city_geoCoord[2][0],latitude=city_geoCoord[2][1])
        .add_coordinate(name=city_names[3],longitude=city_geoCoord[3][0],latitude=city_geoCoord[3][1])
        .add_coordinate(name=city_names[4],longitude=city_geoCoord[4][0],latitude=city_geoCoord[4][1])
        .add_coordinate(name=city_names[5],longitude=city_geoCoord[5][0],latitude=city_geoCoord[5][1])
        .add_coordinate(name=city_names[6],longitude=city_geoCoord[6][0],latitude=city_geoCoord[6][1])
        .add_coordinate(name=city_names[7],longitude=city_geoCoord[7][0],latitude=city_geoCoord[7][1])
        .add_coordinate(name=city_names[8],longitude=city_geoCoord[8][0],latitude=city_geoCoord[8][1])
        .add_coordinate(name=city_names[9],longitude=city_geoCoord[9][0],latitude=city_geoCoord[9][1])
        .add_coordinate(name=city_names[10],longitude=city_geoCoord[10][0],latitude=city_geoCoord[10][1])
        .add_coordinate(name=city_names[11],longitude=city_geoCoord[11][0],latitude=city_geoCoord[11][1])
        .add_coordinate(name=city_names[12],longitude=city_geoCoord[12][0],latitude=city_geoCoord[12][1])
        .add_coordinate(name=city_names[13],longitude=city_geoCoord[13][0],latitude=city_geoCoord[13][1])
        .add_coordinate(name=city_names[14],longitude=city_geoCoord[14][0],latitude=city_geoCoord[14][1])
        .add_coordinate(name=city_names[15],longitude=city_geoCoord[15][0],latitude=city_geoCoord[15][1])
        .add_coordinate(name=city_names[16],longitude=city_geoCoord[16][0],latitude=city_geoCoord[16][1])
        .add_coordinate(name=city_names[17],longitude=city_geoCoord[17][0],latitude=city_geoCoord[17][1])
        .add_coordinate(name=city_names[18],longitude=city_geoCoord[18][0],latitude=city_geoCoord[18][1])
        .add_coordinate(name=city_names[19],longitude=city_geoCoord[19][0],latitude=city_geoCoord[19][1])
        .add_coordinate(name=city_names[20],longitude=city_geoCoord[20][0],latitude=city_geoCoord[20][1])
        .add_coordinate(name=city_names[21],longitude=city_geoCoord[21][0],latitude=city_geoCoord[21][1])
        .add_coordinate(name=city_names[22],longitude=city_geoCoord[22][0],latitude=city_geoCoord[22][1])
        .add_coordinate(name=city_names[23],longitude=city_geoCoord[23][0],latitude=city_geoCoord[23][1])
        .add_coordinate(name=city_names[24],longitude=city_geoCoord[24][0],latitude=city_geoCoord[24][1])
        .add_coordinate(name=city_names[25],longitude=city_geoCoord[25][0],latitude=city_geoCoord[25][1])
        .add_coordinate(name=city_names[26],longitude=city_geoCoord[26][0],latitude=city_geoCoord[26][1])
        .add_coordinate(name=city_names[27],longitude=city_geoCoord[27][0],latitude=city_geoCoord[27][1])
        .add_coordinate(name=city_names[28],longitude=city_geoCoord[28][0],latitude=city_geoCoord[28][1])
        .add_coordinate(name=city_names[29],longitude=city_geoCoord[29][0],latitude=city_geoCoord[29][1])
        .add_coordinate(name=city_names[30],longitude=city_geoCoord[30][0],latitude=city_geoCoord[30][1])
        .add_coordinate(name=city_names[31],longitude=city_geoCoord[31][0],latitude=city_geoCoord[31][1])
        .add_coordinate(name=city_names[32],longitude=city_geoCoord[32][0],latitude=city_geoCoord[32][1])
        .add_coordinate(name=city_names[33],longitude=city_geoCoord[33][0],latitude=city_geoCoord[33][1])

        # 将剧中地图缺少的地方标记出来
        .add(
            "中国各省会城市地图",
            [[city_names[0],10], [city_names[1], 10], [city_names[2], 10], [city_names[3], 10], [city_names[4], 10],
            [city_names[5], 10],[city_names[6], 10],[city_names[7], 10],[city_names[8], 10],[city_names[9], 10],[city_names[10], 10],
            [city_names[11], 10],[city_names[12], 10],[city_names[13], 10],[city_names[14], 10],[city_names[15], 10],[city_names[16], 10],
            [city_names[17], 10],[city_names[18], 10],[city_names[19], 10],[city_names[20], 10],[city_names[21], 10],[city_names[22], 10],
            [city_names[23], 10],[city_names[24], 10],[city_names[25], 10],[city_names[26], 10],[city_names[27], 10],[city_names[28], 10],
            [city_names[29], 10],[city_names[30], 10],[city_names[31], 10],[city_names[32], 10],[city_names[33], 10]],
            type_=ChartType.EFFECT_SCATTER,
        )
        # 显示出这个点的标签（formatter={b} 表示显示地区名称，详细可见：
        #  https://pyecharts.org/#/zh-cn/series_options ）
        .set_series_opts(label_opts=opts.LabelOpts(is_show=True, formatter="{b}", font_size=8))
        # 设置地图名称，即左上角
        .set_global_opts(title_opts=opts.TitleOpts(title="中国地图"))
    )
    return c    

# 生成对象
c = geo_effectscatter()

# 渲染地图
c.render()

# 生成图片
make_snapshot(snapshot, c.render(), "map_marked.png")

# %%
plt.figure(figsize=(16,16))
img = plt.imread("map_marked.png")
# fig, ax = plt.subplots()
plt.imshow(img, extent=[0, 1800, 0, 1000])

plt.show()
